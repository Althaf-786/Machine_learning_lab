# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
import pandas as pd
import numpy as np

# %%
#Load the data sets- train and test 
dataframe=pd.read_csv('train.csv')

# %%
#Look at top values of train data 
dataframe.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print the column names of train data
dataframe.columns
dataframe.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Print the dimension of train and test data
dataframe.shape
# Out:
# (891, 12)

# %%
#Print the number of missing values in each column of train and test data
print("Missing values in train data:")
print(dataframe.isnull().sum())

print("\nMissing values in test data:")
print(dataframe.isnull().sum())

print("\nMissing values in train data:")
print(dataframe.isnull().sum()[dataframe.isnull().sum() > 0])

print("\nMissing values in test data:")
print(dataframe.isnull().sum()[dataframe.isnull().sum() > 0])
# Out:
# Missing values in train data:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Missing values in test data:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Missing values in train data:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64
#
# Missing values in test data:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("train.csv")

# Define categorical columns
categorical_cols = ['Survived', 'Pclass', 'Sex', 'Embarked']

# Set figure size
plt.figure(figsize=(8, 8))

# Loop through categorical columns
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(2, 2, i)  # Create subplots in a 2x2 grid
    sns.countplot(data=df, x=col, hue=col, legend=True)
    plt.title(f"Count of {col}")

plt.tight_layout()
plt.show()

# %%
#Histogram of Age, Parch, Fare
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset

# Set the style
sns.set_style("whitegrid")

# Define numerical columns
numerical_cols = ['Age', 'Parch', 'Fare','Pclass']

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(15, 5))

# Loop through the columns and create histograms
for col, ax in zip(numerical_cols, axes):
    sns.histplot(data=df, x="Age", hue="Sex", bins=30, kde=True, palette="viridis", ax=ax)
    ax.set_title(f"Distribution of {col}")

plt.tight_layout()
plt.show()

# %%
colors = ["red", "blue", "green", "black"]  # List of colors
cols = ["Age", "Fare", "Parch",'Pclass']  # Columns to plot

plt.figure(figsize=(12, 6))

for i, col in enumerate(cols):
    plt.subplot(1, 4, i+1)  # Create subplots
    sns.histplot(df[col], bins=30, kde=True, color=colors[i])  # Assign different colors
    plt.title(f"Histogram of {col}")

plt.tight_layout()
plt.show()

# %%
#Plot histogram of age for survived and did not survived class
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
sns.set_style("whitegrid")

# Create the histogram
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x="Age", hue="Survived", bins=30, kde=True, palette=["red", "green"], alpha=0.6)

# Labels and title
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution for Survived and Did Not Survive")

# Show plot
plt.show()

# %%
#Count class and geder wise survival rate - plot with appropriate chart
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
sns.set_style("whitegrid")

# Create a grouped bar chart
plt.figure(figsize=(8, 6))
sns.catplot(data=df, x="Pclass", hue="Sex", col="Survived", kind="count", palette="Set2", height=5, aspect=1)

plt.suptitle("Class & Gender-wise Survival Rate", y=1.05)
plt.show()

#Age wise Distribution of Male and Female passengers
# Create the histogram
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x="Age", hue="Sex", bins=30, kde=True, palette=["blue", "pink"], alpha=0.6)

# Labels and title
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age-wise Distribution of Male and Female Passengers")

# Show plot
plt.show()

# %%
#Histogram of Age of the given data set(sample)
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
sns.set_style("whitegrid")

# Plot histogram of Age
plt.figure(figsize=(10, 5))
sns.histplot(df["Age"], bins=30, kde=True, color="blue", alpha=0.6)

# Labels and title
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Histogram of Age in the Dataset")

# Show plot
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'
df['Embarked'].fillna('S', inplace=True)
print(df['Embarked'].isnull().sum())
# Out:
# 0

# %%
#Impute the missing values in Fare column with median value
df['Fare'].fillna(df['Fare'].median(), inplace=True)
print(df['Fare'].isnull().sum())  # Should print 0
# Out:
# 0
# /tmp/ipykernel_6182/3913222399.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(df['Fare'].median(), inplace=True)

# %%
# Calculate mean and standard deviation of non-missing Age values
mean_age = df['Age'].mean()
std_age = df['Age'].std()

# Generate random values following the same distribution
random_ages = np.random.normal(mean_age, std_age, df['Age'].isnull().sum())

# Assign these values to the missing Age entries
df.loc[df['Age'].isnull(), 'Age'] = random_ages

print(df['Age'].isnull().sum())  # Should print 0
print(mean_age)
print(std_age)
print(random_ages)
# Out:
# 0
# 29.47479262111038
# 14.338059901706243
# []

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
s=df['FamilySize']
print(s)

#FamilySize = Parch + SibSp + 1
df[['SibSp', 'Parch', 'FamilySize']].head()
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: FamilySize, Length: 891, dtype: int64
#    SibSp  Parch  FamilySize
# 0      1      0           2
# 1      1      0           2
# 2      0      0           1
# 3      1      0           2
# 4      0      0           1

# %%
# Create new feature IsAlone from FamilySize
df['IsAlone'] = df['FamilySize'] == 1

#If FamilySize == 1 then IsAlone = True else IsAlone = False
df[['FamilySize', 'IsAlone']].head()
# Out:
#    FamilySize  IsAlone
# 0           2    False
# 1           2    False
# 2           1     True
# 3           2    False
# 4           1     True

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Drop the columns which may not be useful in prediction of survival

#Drop PassengerId, Name, Ticket, and Cabin
df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace=True)
print(df.columns)
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'FamilySize', 'IsAlone'],
#       dtype='object')

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y
# Define target variable (y)
y = df['Survived']

# Define feature set (X) by dropping the target column
X = df.drop(columns=['Survived'])

# Verify the shapes of X and y
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (891, 9)
# Shape of y: (891,)

# %%
# Label encoding of categorical features
from sklearn.preprocessing import LabelEncoder

# Identify categorical columns
categorical_cols = ['Sex', 'Embarked', 'IsAlone']  # Add any other categorical features if needed

# Initialize LabelEncoder
le = LabelEncoder()

# Apply Label Encoding to each categorical column
for col in categorical_cols:
    X[col] = le.fit_transform(X[col])

# Verify encoding
print(X.head())
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  IsAlone
# 0       3    1  22.0      1      0   7.2500         2           2        0
# 1       1    0  38.0      1      0  71.2833         0           2        0
# 2       3    0  26.0      0      0   7.9250         2           1        1
# 3       1    0  35.0      1      0  53.1000         2           2        0
# 4       3    1  35.0      0      0   8.0500         2           1        1

# %%
# concat df_categorical with original df
from sklearn.preprocessing import LabelEncoder

# Identify categorical columns
categorical_cols = ['Sex', 'Embarked', 'IsAlone']  # Add any other categorical features if needed

# Initialize LabelEncoder
le = LabelEncoder()

# Apply Label Encoding to each categorical column and store in df_categorical
df_categorical = df[categorical_cols].apply(le.fit_transform)

# Verify encoding
print(df_categorical.head())

df = pd.concat([df, df_categorical], axis=1)

# Drop original categorical columns if necessary
df.drop(columns=categorical_cols, inplace=True)

# Verify the updated DataFrame
print(df.head())
# Out:
#    Sex  Embarked  IsAlone
# 0    1         2        0
# 1    0         0        0
# 2    0         2        1
# 3    0         2        0
# 4    1         2        1
#    Survived  Pclass   Age  SibSp  Parch     Fare  FamilySize
# 0         0       3  22.0      1      0   7.2500           2
# 1         1       1  38.0      1      0  71.2833           2
# 2         1       3  26.0      0      0   7.9250           1
# 3         1       1  35.0      1      0  53.1000           2
# 4         0       3  35.0      0      0   8.0500           1

# %%
#Do a pairplot of all features
import seaborn as sns
import matplotlib.pyplot as plt

# Create the pairplot
sns.pairplot(df, diag_kind="kde")  # kde for smooth distribution on diagonal

# Show the plot
plt.show()

# %%
X
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         3    1  22.000000      1      0   7.2500         2           2
# 1         1    0  38.000000      1      0  71.2833         0           2
# 2         3    0  26.000000      0      0   7.9250         2           1
# 3         1    0  35.000000      1      0  53.1000         2           2
# 4         3    1  35.000000      0      0   8.0500         2           1
# ..      ...  ...        ...    ...    ...      ...       ...         ...
# 886       2    1  27.000000      0      0  13.0000         2           1
# 887       1    0  19.000000      0      0  30.0000         2           1
# 888       3    0  23.056782      1      2  23.4500         2           4
# 889       1    1  26.000000      0      0  30.0000         0           1
# 890       3    1  32.000000      0      0   7.7500         1           1
#
#      IsAlone
# 0          0
# 1          0
# 2          1
# 3          0
# 4          1
# ...

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# Print shapes to verify
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)
print("y_train shape:", y_train.shape)
print("y_validation shape:", y_validation.shape)
# Out:
# X_train shape: (801, 9)
# X_validation shape: (90, 9)
# y_train shape: (801,)
# y_validation shape: (90,)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier

# Initialize the model with default hyperparameters
model = DecisionTreeClassifier(random_state=42)

# Fit the model to the training data
model.fit(X_train, y_train)

# Print model details
print("Decision Tree Model Trained Successfully!")
# Out:
# Decision Tree Model Trained Successfully!

# %%
#Print the tree

# Importing required packages for visualization
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(12, 8))

# Plot the decision tree
plot_tree(model, feature_names=X.columns, class_names=['Not Survived', 'Survived'], filled=True)

# Show the plot
plt.show()

# %%
# plotting tree with max_depth=3
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(12, 8))

# Plot the decision tree with max_depth=3
plot_tree(model, feature_names=X.columns, class_names=['Not Survived', 'Survived'], filled=True, max_depth=3)

# Show the plot
plt.show()

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Make predictions on the validation set
y_pred = model.predict(X_validation)

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_validation, y_pred)

# Compute accuracy
accuracy = accuracy_score(y_validation, y_pred)

# Print the classification report (Precision, Recall, F1-score)
class_report = classification_report(y_validation, y_pred)

# Display results
print("Confusion Matrix:\n", conf_matrix)
print("\nAccuracy:", accuracy)
print("\nClassification Report:\n", class_report)
# Out:
# Confusion Matrix:
#  [[37 18]
#  [ 9 26]]
#
# Accuracy: 0.7
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        55
#            1       0.59      0.74      0.66        35
#
#     accuracy                           0.70        90
#    macro avg       0.70      0.71      0.70        90
# weighted avg       0.72      0.70      0.70        90

# %%
# Printing confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score

# Make predictions on the validation set
y_pred = model.predict(X_validation)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_validation, y_pred)

# Compute accuracy
accuracy = accuracy_score(y_validation, y_pred)

# Display results
print("Confusion Matrix:\n", conf_matrix)
print("\nAccuracy:", accuracy)
# Out:
# Confusion Matrix:
#  [[37 18]
#  [ 9 26]]
#
# Accuracy: 0.7

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions
y_pred_rf = rf_model.predict(X_validation)

# Compute accuracy
accuracy_rf = accuracy_score(y_validation, y_pred_rf)

# Display accuracy
print("Random Forest Accuracy:", accuracy_rf)
# Out:
# Random Forest Accuracy: 0.7555555555555555

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Initialize the Gradient Boosting model
gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)

# Train the model
gb_model.fit(X_train, y_train)

# Make predictions
y_pred_gb = gb_model.predict(X_validation)

# Compute accuracy
accuracy_gb = accuracy_score(y_validation, y_pred_gb)

# Display accuracy
print("Gradient Boosting Accuracy:", accuracy_gb)
# Out:
# Gradient Boosting Accuracy: 0.8
