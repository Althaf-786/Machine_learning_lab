# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in ./anaconda3/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in ./anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in ./anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in ./anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
import pandas as pd
import numpy as np

# %%
dataframe=pd.read_csv("tvmarketing.csv")

# %%
dataframe
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
dataframe.iloc[0:6]
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9
# 5    8.7    7.2

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
print(dataframe.shape)
# Out:
# (200, 2)

# %%
print(dataframe
      .describe())
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 1. Import dataset and display first 5 rows
df = pd.read_csv("tvmarketing.csv")
print("First 5 rows:\n", df.head())
# Out:
# First 5 rows:
#        TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
# 2. Check column data types
print("\nData types:\n", df.dtypes)
# Out:
# Data types:
#  TV       float64
# Sales    float64
# dtype: object

# %%
# 3. Check the shape of the DataFrame
print("\nShape of DataFrame:", df.shape)
# Out:
# Shape of DataFrame: (200, 2)

# %%
# 4. Summary statistics
print("\nSummary Statistics:\n", df.describe())
# Out:
# Summary Statistics:
#                 TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
# 5. Visualize relationship using scatterplot
plt.scatter(df['TV'], df['Sales'], color='blue')
plt.xlabel('TV Marketing Budget')
plt.ylabel('Sales')
plt.title('TV Marketing Budget vs Sales')
plt.show()

# %%
# 6. Prepare X and y
X = df[['TV']]
y = df['Sales']

# %%
X
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# 7. Split Data into Training and Testing Sets (70% Train, 30% Test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#         TV
# 169  284.3
# 97   184.9
# 31   112.9
# 12    23.8
# 35   290.7
# ..     ...
# 106   25.0
# 14   204.1
# 92   217.7
# 179  165.6
# 102  280.2
#
# [140 rows x 1 columns]

# %%
# 8. Print the shape of train data and test data
print("\nTrain Data Shape:", X_train.shape, y_train.shape)
print("Test Data Shape:", X_test.shape, y_test.shape)
# Out:
# Train Data Shape: (140, 1) (140,)
# Test Data Shape: (60, 1) (60,)

# %%
# 9. Perform Linear Regression manually (without library)
n = len(X_train)
X_mean = X_train.mean().values[0]
y_mean = y_train.mean()
m = sum((X_train['TV'] - X_mean) * (y_train - y_mean)) / sum((X_train['TV'] - X_mean) ** 2)
b = y_mean - m * X_mean
print("\nManual Linear Regression Coefficients:")
print("Slope (m):", m)
print("Intercept (b):", b)
# Out:
# Manual Linear Regression Coefficients:
# Slope (m): 0.046407802128152764
# Intercept (b): 7.239459830751138

# %%
# 10. Make predictions using manual model
y_pred_manual = m * X_test['TV'] + b

# %%
# 11. Perform Linear Regression using sklearn
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 12. Print intercept and coefficients
print("\nSklearn Linear Regression Coefficients:")
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_[0])
# Out:
# Sklearn Linear Regression Coefficients:
# Intercept: 7.23945983075114
# Coefficient: 0.04640780212815275

# %%
# 13. Make predictions on the testing set
y_pred_sklearn = model.predict(X_test)

# %%
# 13. Make predictions on the testing set
y_pred_sklearn = model.predict(X_test)

# %%
y_pred_sklearn
# Out:
# array([14.81785392, 16.30754437, 20.83230507,  7.78243112, 17.46309864,
#        10.72468577, 17.30067133,  9.55984994, 17.56055502, 15.36546598,
#         8.7013056 ,  9.84757831, 18.12208943,  7.49006196, 13.71334823,
#        15.13806775,  7.57823679, 16.40964153, 10.73396733, 18.25667206,
#        17.89005042, 10.38590882,  9.00295631, 18.88317738, 10.44159818,
#         9.72227724, 17.14752559, 13.70406667, 11.28622018,  7.62928537,
#        16.5117387 , 10.45087974, 16.46997167,  8.02375169, 20.26612989,
#        18.2937983 ,  9.48095667, 19.94127527, 12.67845424,  8.51567439,
#        12.62276488, 15.45364081,  9.2396361 , 10.1306659 , 17.63480751,
#         9.01223787, 10.51585066, 14.07532908, 12.09371593, 10.78037513,
#        10.86854996, 15.05453371,  7.64320771,  7.60144069, 10.78501591,
#        13.24462943, 10.64579251, 20.68380011,  8.14905275, 16.40964153])

# %%
# 14. Plot train data and model
plt.scatter(X_train, y_train, color='blue', label='Train Data')
plt.plot(X_train, model.predict(X_train), color='red', label='Fitted Line')
plt.xlabel('TV Marketing Budget')
plt.ylabel('Sales')
plt.title('Train Data & Model')
plt.legend()
plt.show()

# %%
# 15. Plot test data and model
plt.scatter(X_test, y_test, color='green', label='Test Data')
plt.plot(X_test, model.predict(X_test), color='red', label='Fitted Line')
plt.xlabel('TV Marketing Budget')
plt.ylabel('Sales')
plt.title('Test Data & Model')
plt.legend()
plt.show()

# %%
# 16. Print Mean Squared Error and R Squared Value
mse = mean_squared_error(y_test, y_pred_sklearn)
r2 = r2_score(y_test, y_pred_sklearn)
print("\nMean Squared Error:", mse)
print("R Squared Value:", r2)
# Out:
# Mean Squared Error: 8.970991242413616
# R Squared Value: 0.6714477229302764

# %%
# 17. Calculate and print R Squared and Adjusted R Squared without library
ss_total = sum((y_test - y_test.mean())**2)
ss_residual = sum((y_test - y_pred_manual)**2)
manual_r2 = 1 - (ss_residual / ss_total)
adjusted_r2 = 1 - (1 - manual_r2) * (len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1)

print("\nManual R Squared:", manual_r2)
print("Manual Adjusted R Squared:", adjusted_r2)
# Out:
# Manual R Squared: 0.6714477229302767
# Manual Adjusted R Squared: 0.66578302849804

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0])],remainder='passthrough')

# %%
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(), [0])])

# %%
x=np.array(ct.fit_transform(df[0:5]))

# %%
x
# Out:
# array([[ 0. ,  0. ,  0. ,  0. ,  1. , 22.1],
#        [ 0. ,  1. ,  0. ,  0. ,  0. , 10.4],
#        [ 1. ,  0. ,  0. ,  0. ,  0. ,  9.3],
#        [ 0. ,  0. ,  1. ,  0. ,  0. , 18.5],
#        [ 0. ,  0. ,  0. ,  1. ,  0. , 12.9]])

# %%
print(x)
# Out:
# [[ 0.   0.   0.   0.   1.  22.1]
#  [ 0.   1.   0.   0.   0.  10.4]
#  [ 1.   0.   0.   0.   0.   9.3]
#  [ 0.   0.   1.   0.   0.  18.5]
#  [ 0.   0.   0.   1.   0.  12.9]]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
Y=le.fit_transform(y)

# %%
Y#here it will be replacing the main numbers with the lables 22.1->label is->106
# Out:
# array([106,  31,  23,  89,  54,  12,  44,  55,   2,  33,  19,  84,  22,
#         27,  91, 109,  50, 115,  39,  64,  86,  50,   5,  71,  27,  46,
#         68,  74,  90,  32, 102,  45,  26,  84,  25,  53, 117,  65,  29,
#        103,  77,  81,  99,  54,  18,  67,  33, 111,  66,  27,  40,  34,
#        110, 101,  98, 112,   4,  55, 113,  88,  16, 114,  73,  59,  86,
#         23,  25,  57,  90, 108,  87,  49,  21,  37,  80,  20,  10,  61,
#          3,  37,  44,  48,  39,  58, 104,  69,  46,  75,  54,  78,  38,
#         13,  93, 107,  41,  79,  43,  71, 117,  82,  43, 113,  66,  65,
#         99,  92,  12,  20,   3,  96,  57, 105,  60,  74,  64,  51,  47,
#         24,  74,   8,  71,  11,  42,  69,  95,  33,   8,  21, 116,  27,
#          0,  52,   6,  94,  35,  42,  25, 100,  26,  99,  36,  92,  97,
#         31,  40,  30,  55, 117,  36,  29,  76,  42,  77,  91,  72,   1,
#         70,  29,  13,  54,  62,  56,  67,  86,  45,  45,  15,  47,  81,
#         68,  17,  63,  14,  43,  41, 120,  98,  43,  44,  51,  32,  47,
#         20, 119,  85, 110,  30,  83,  74,   9,  35,  28,   7,  94,  83,
#         14,  27,  53, 118,  57])

# %%
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
print(le.classes_)  #
# Out:
# [ 1.6  3.2  4.8  5.3  5.5  5.6  5.7  5.9  6.6  6.7  6.9  7.   7.2  7.3
#   7.6  8.   8.1  8.4  8.5  8.6  8.7  8.8  9.2  9.3  9.4  9.5  9.6  9.7
#   9.9 10.1 10.3 10.4 10.5 10.6 10.7 10.8 10.9 11.  11.2 11.3 11.4 11.5
#  11.6 11.7 11.8 11.9 12.  12.2 12.3 12.4 12.5 12.6 12.7 12.8 12.9 13.2
#  13.3 13.4 13.6 14.  14.1 14.2 14.4 14.5 14.6 14.7 14.8 14.9 15.  15.2
#  15.3 15.5 15.6 15.7 15.9 16.  16.1 16.6 16.7 16.9 17.  17.1 17.2 17.3
#  17.4 17.6 18.  18.3 18.4 18.5 18.9 19.  19.2 19.4 19.6 19.7 19.8 20.1
#  20.2 20.7 20.8 21.2 21.4 21.5 21.7 21.8 22.1 22.2 22.3 22.4 22.6 23.2
#  23.7 23.8 24.2 24.4 24.7 25.4 25.5 26.2 27. ]
